# %% [markdown]
# Beginning

# %%
# Import Modules

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %%
# Upload the csv, store it in 'df' which is a variable
df = pd.read_csv('vgsales.csv')

# %%
# Shape shows rows and columns
df.shape
# Out:
# (16598, 11)

# %%
# Table view, put in bracket is top 10
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
# Show the coloumn data types
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# Describe shows basic information about my data such as mean, count, etc.
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# Data Preparation
# - Cleaning
# - Renaming column etc

# %%
# Show columns, so you can copy them to next code
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# This way you drop only NA_Sales
#df.drop(['NA_Sales'], axis=1)

# %%
# Remove the column you dont want, we will comment it out just to show it later. I am also storing it as the new "df" going forward df = the code
df = df[[#'Rank', 
    'Year',
    'Name',
    'Platform',
    'Genre',
    'Publisher',
    'NA_Sales',
    'EU_Sales',
    'JP_Sales',
    'Other_Sales',
    'Global_Sales'
    ]]

# %%
df['Year'] #Year is not in right format
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: Year, Length: 16598, dtype: float64

# %%
# Use this later
#df['Year'] = df['Year'].astype(int)

# check this as well --- pd.to_numeric(df['Year']) # pd.to_numeric changes it

# %%
#df['Year'] = df['Year'].astype(int)
# This didnt work because It seems like the 'Year' column in your DataFrame contains non-finite values (NA or inf), which is causing the IntCastingNaNError when trying to convert to an integer type. To resolve this, you can first handle the missing values and then convert the 'Year' column to integers.

# %%
# Rename the columns
#df.columns
# NO NEED TO RENAME COLUMNS

#df.rename(columns = {'Rank':'No',               #Change Rank to No
#                     'Platform':'Console',      #Change Platform to Console
#                    'Genre':'Type'})           #you get the drift

# %% [markdown]
# Replace dataframe

# %%
# Check Data again
df.head()
# Out:
#      Year                      Name Platform         Genre Publisher  \
# 0  2006.0                Wii Sports      Wii        Sports  Nintendo
# 1  1985.0         Super Mario Bros.      NES      Platform  Nintendo
# 2  2008.0            Mario Kart Wii      Wii        Racing  Nintendo
# 3  2009.0         Wii Sports Resort      Wii        Sports  Nintendo
# 4  1996.0  Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Check for missing values in each columns
df.isna()
# Out:
#         Year   Name  Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      False  False     False  False      False     False     False     False
# 1      False  False     False  False      False     False     False     False
# 2      False  False     False  False      False     False     False     False
# 3      False  False     False  False      False     False     False     False
# 4      False  False     False  False      False     False     False     False
# ...      ...    ...       ...    ...        ...       ...       ...       ...
# 16593  False  False     False  False      False     False     False     False
# 16594  False  False     False  False      False     False     False     False
# 16595  False  False     False  False      False     False     False     False
# 16596  False  False     False  False      False     False     False     False
# 16597  False  False     False  False      False     False     False     False
#
#        Other_Sales  Global_Sales
# ...

# %%
# Instead of getting the "false", why dont we count the number
df.isna().sum()
# Out:
# Year            271
# Name              0
# Platform          0
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df = df.dropna(subset=['Year']) # Removed empty fields in Year column and passed new table into df

# %%
df.isna().sum() #Check
# Out:
# Year             0
# Name             0
# Platform         0
# Genre            0
# Publisher       36
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
df.loc[df.duplicated()] #locate the duplicate
# Out:
#        Year                         Name Platform    Genre Publisher  \
# 14999   NaN  Wii de Asobu: Metroid Prime      Wii  Shooter  Nintendo
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 14999       0.0       0.0      0.02          0.0          0.02

# %%
df.duplicated(subset=['Year']) #Check duplicate by column
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593     True
# 16594     True
# 16595     True
# 16596     True
# 16597     True
# Length: 16598, dtype: bool

# %%
## df.loc[df.duplicated(subset=['Publisher'])] #locate the duplicates

# %%
#I want to see why Madden is duplicated by using the query function
df.query('Name =="Madden NFL 13"')
# Out:
#          Year           Name Platform   Genre        Publisher  NA_Sales  \
# 506    2012.0  Madden NFL 13     X360  Sports  Electronic Arts      2.53
# 603    2012.0  Madden NFL 13      PS3  Sports  Electronic Arts      2.11
# 3730   2012.0  Madden NFL 13      Wii  Sports  Electronic Arts      0.51
# 5588   2012.0  Madden NFL 13      PSV  Sports  Electronic Arts      0.30
# 6792   2012.0  Madden NFL 13     WiiU  Sports  Electronic Arts      0.22
# 16127  2012.0  Madden NFL 13      PS3  Sports  Electronic Arts      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 506        0.16       0.0         0.17          2.86
# 603        0.23       0.0         0.22          2.56
# 3730       0.00       0.0         0.03          0.54
# 5588       0.00       0.0         0.03          0.32
# 6792       0.00       0.0         0.02          0.24
# 16127      0.01       0.0         0.00          0.01

# %%
df.duplicated(subset=['Name','Platform']).sum() #Checking where we have Name and Platform are the same
# Out:
# 3

# %%
~df.duplicated(subset=['Name','Platform']) #~ inverts the code, so instead of false and result, you get true
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 16593    True
# 16594    True
# 16595    True
# 16596    True
# 16597    True
# Length: 16327, dtype: bool

# %%
df.loc[~df.duplicated(subset=['Name','Platform'])] #Now i want to locate them.
# Out:
#          Year                                              Name Platform  \
# 0      2006.0                                        Wii Sports      Wii
# 1      1985.0                                 Super Mario Bros.      NES
# 2      2008.0                                    Mario Kart Wii      Wii
# 3      2009.0                                 Wii Sports Resort      Wii
# 4      1996.0                          Pokemon Red/Pokemon Blue       GB
# ...       ...                                               ...      ...
# 16593  2002.0                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  2003.0                     Men in Black II: Alien Escape       GC
# 16595  2008.0  SCORE International Baja 1000: The Official Game      PS2
# 16596  2010.0                                        Know How 2       DS
# 16597  2003.0                                  Spirits & Spells      GBA
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# Now that you have droped the rows, the index 1 - 16593 wont follow, for example look at index 16593, it doesnt match Serial No 16596, we now have to reset the index, see code below

# %%
df.loc[~df.duplicated(subset=['Name','Platform'])] \
    .reset_index()
# Out:
#        index    Year                                              Name  \
# 0          0  2006.0                                        Wii Sports
# 1          1  1985.0                                 Super Mario Bros.
# 2          2  2008.0                                    Mario Kart Wii
# 3          3  2009.0                                 Wii Sports Resort
# 4          4  1996.0                          Pokemon Red/Pokemon Blue
# ...      ...     ...                                               ...
# 16319  16593  2002.0                Woody Woodpecker in Crazy Castle 5
# 16320  16594  2003.0                     Men in Black II: Alien Escape
# 16321  16595  2008.0  SCORE International Baja 1000: The Official Game
# 16322  16596  2010.0                                        Know How 2
# 16323  16597  2003.0                                  Spirits & Spells
#
#       Platform         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# But we dont want the index column, so we drop that column

# %%
df.loc[~df.duplicated(subset=['Name','Platform'])] \
    .reset_index(drop=True)
# Out:
#          Year                                              Name Platform  \
# 0      2006.0                                        Wii Sports      Wii
# 1      1985.0                                 Super Mario Bros.      NES
# 2      2008.0                                    Mario Kart Wii      Wii
# 3      2009.0                                 Wii Sports Resort      Wii
# 4      1996.0                          Pokemon Red/Pokemon Blue       GB
# ...       ...                                               ...      ...
# 16319  2002.0                Woody Woodpecker in Crazy Castle 5      GBA
# 16320  2003.0                     Men in Black II: Alien Escape       GC
# 16321  2008.0  SCORE International Baja 1000: The Official Game      PS2
# 16322  2010.0                                        Know How 2       DS
# 16323  2003.0                                  Spirits & Spells      GBA
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.shape
# Out:
# (16327, 10)

# %% [markdown]
# Feauture Understanding (Univariate analysis)
# - Histogram
# - KDE
# - Boxplot

# %%
df['Year'].value_counts() #Check most comon year
# Out:
# Year
# 2009    1431
# 2008    1428
# 2010    1259
# 2007    1202
# 2011    1139
# 2006    1008
# 2005     941
# 2002     829
# 2003     775
# 2004     763
# 2012     657
# 2015     614
# 2014     582
# 2013     546
# 2001     482
# 1998     379
# 2000     349
# 2016     344
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# 2017       3
# 2020       1
# Name: count, dtype: int64

# %%
df['Year'].value_counts() \
    .head(10) #Top 10 mist occuring Years, the "\" only allows the code enter next line and nice to read.
# Out:
# Year
# 2009    1431
# 2008    1428
# 2010    1259
# 2007    1202
# 2011    1139
# 2006    1008
# 2005     941
# 2002     829
# 2003     775
# 2004     763
# Name: count, dtype: int64

# %%
df['Year'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Year with most games released') #bar chart replace bar with barh for horizontal bar
# Out:
# <Axes: title={'center': 'Year with most games released'}, xlabel='Year'>

# %%
#Save as matplotlib axis
ax = df['Year'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years with most games released')
ax.set_xlabel('Year introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df
# Out:
#        Year                                              Name Platform  \
# 0      2006                                        Wii Sports      Wii
# 1      1985                                 Super Mario Bros.      NES
# 2      2008                                    Mario Kart Wii      Wii
# 3      2009                                 Wii Sports Resort      Wii
# 4      1996                          Pokemon Red/Pokemon Blue       GB
# ...     ...                                               ...      ...
# 16593  2002                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  2003                     Men in Black II: Alien Escape       GC
# 16595  2008  SCORE International Baja 1000: The Official Game      PS2
# 16596  2010                                        Know How 2       DS
# 16597  2003                                  Spirits & Spells      GBA
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#Histogram
df['Year'].plot(kind='hist', bins=30) #bins is to group the histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Density Plot
df['Year'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Feature Relationships
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Groupby comparisons

# %%
df.plot(kind = 'scatter',
        x = 'Year',
        y = 'Global_Sales',
        title = 'Sales by Year')
plt.show() #wont show this nonsense <Axes: title={'center': 'NA Sales by Year'}, xlabel='Year', ylabel='NA_Sales'>

# %%
sns.scatterplot(x = 'Year',
                y = 'Global_Sales',
                data = df) #seaborn has more features
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
sns.scatterplot(x = 'Year',
                y = 'Global_Sales',
                hue = 'Year',
                data = df)
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
df
# Out:
#        Year                                              Name Platform  \
# 0      2006                                        Wii Sports      Wii
# 1      1985                                 Super Mario Bros.      NES
# 2      2008                                    Mario Kart Wii      Wii
# 3      2009                                 Wii Sports Resort      Wii
# 4      1996                          Pokemon Red/Pokemon Blue       GB
# ...     ...                                               ...      ...
# 16593  2002                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  2003                     Men in Black II: Alien Escape       GC
# 16595  2008  SCORE International Baja 1000: The Official Game      PS2
# 16596  2010                                        Know How 2       DS
# 16597  2003                                  Spirits & Spells      GBA
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
sns.pairplot(df, vars=['Year','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales'])
plt.show()
# Out:
# C:\Users\mayow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df[[#'Year',
    'NA_Sales',
    'EU_Sales',
    'JP_Sales',
    'Other_Sales',
    'Global_Sales'
    ]].corr() #checking correlation
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# NA_Sales      1.000000  0.768936  0.451285     0.634508      0.941268
# EU_Sales      0.768936  1.000000  0.436414     0.726266      0.903271
# JP_Sales      0.451285  0.436414  1.000000     0.290653      0.612794
# Other_Sales   0.634508  0.726266  0.290653     1.000000      0.747974
# Global_Sales  0.941268  0.903271  0.612794     0.747974      1.000000

# %%
#pass above code into a dataframe to reference later
df_corr = df[[#'Year',
    'NA_Sales',
    'EU_Sales',
    'JP_Sales',
    'Other_Sales',
    'Global_Sales'
    ]].corr() #checking correlation

# %%
df_corr #calling it
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# NA_Sales      1.000000  0.768936  0.451285     0.634508      0.941268
# EU_Sales      0.768936  1.000000  0.436414     0.726266      0.903271
# JP_Sales      0.451285  0.436414  1.000000     0.290653      0.612794
# Other_Sales   0.634508  0.726266  0.290653     1.000000      0.747974
# Global_Sales  0.941268  0.903271  0.612794     0.747974      1.000000

# %%
sns.heatmap(df_corr) #using seaborn's heatmap
# Out:
# <Axes: >

# %%
sns.heatmap(df_corr, annot=True) #add anotations
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Year                      Name Platform         Genre Publisher  NA_Sales  \
# 0  2006                Wii Sports      Wii        Sports  Nintendo     41.49
# 1  1985         Super Mario Bros.      NES      Platform  Nintendo     29.08
# 2  2008            Mario Kart Wii      Wii        Racing  Nintendo     15.85
# 3  2009         Wii Sports Resort      Wii        Sports  Nintendo     15.75
# 4  1996  Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
c = df.groupby('Year')['Global_Sales'].sum()
c = c.sort_values(ascending=False)
c.head()
# Out:
# Year
# 2008    678.90
# 2009    667.30
# 2007    611.13
# 2010    600.45
# 2006    521.04
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Questions
# - what type of game sold most in EU
# -

# %%
filtered_df = df[df['Console'] == 'Wii']

# %%
average_eu_sales = filtered_df['EU_Sales'].mean()

# %%
average_eu_sales
# Out:
# 0.20255094339622642
