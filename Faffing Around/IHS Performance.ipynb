# %% [markdown]
# Import Libraries

# %%
import pandas as pd

# %%
df = pd.read_excel('ihs.xlsx')

# %%
df
# Out:
#                 Unnamed: 0      Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0                      NaN             NaN        NaN        NaN         NaN
# 1                 Clusters  Count of Site       Urban      Rural         NaN
# 2                Abuja Rd               22         17          5         NaN
# 3                  Bauchi               21         18          3         NaN
# 4                   JOS 1               27         24          3         NaN
# 5                   JOS 2               24         23          1         NaN
# 6                Rayfield               27         27          0         NaN
# 7                Zaria Rd               13          8          5         NaN
# 8                 Kaduna 1              23         23          0         NaN
# 9                 Kaduna 2              20         15          5         NaN
# 10                Kaduna 3              20         20          0         NaN
# ...
